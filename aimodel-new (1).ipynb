# %% [markdown]
# 摄像头与华为云同步代码

# %%
# 🔥 Jupyter 必须加这一行，才能显示图像
# %matplotlib inline

from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from IPython.display import clear_output
import numpy as np
import time
import json
import paho.mqtt.client as mqtt
from paho.mqtt.client import CallbackAPIVersion   # 使用 VERSION2 API

# ==================== 强制中文正常显示 ====================
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = (10, 6)

# ==================== 华为云 IoT 设备信息====================
CLIENT_ID = "6a44f1107f2e6c302f80df88_farmeye-1_0_0_2026070110"  
USERNAME  = "6a44f1107f2e6c302f80df88_farmeye-1"
PASSWORD  = "76fb0e768bbeb4f53f4b38b9dab54d4dadb833b3f1d1fecc6a2f8b36afdffeb6"
HOST      = "a963d886c0.st1.iotda-device.cn-north-4.myhuaweicloud.com"
PORT      = 1883

# 属性上报主题
TOPIC_PROPERTY = f"$oc/devices/{CLIENT_ID}/sys/properties/report"
# 告警事件上报主题
TOPIC_ALERT    = f"$oc/devices/{CLIENT_ID}/sys/events/up"

# ==================== 模型路径 ====================
model_path = r'D:\微信QQ\FireDetection\runs\detect\runs\detect\xiaomai_model\weights\best.pt'
model = YOLO(model_path, task='detect')

# ==================== 打开摄像头 ====================
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("摄像头打开失败")
    exit()

# ==================== MQTT 连接函数（与模拟器相同的 VERSION2）====================
def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("✅ 华为云IoT连接认证成功！")
        else:
            print(f"❌ 连接失败，错误码：{rc}")

    def on_disconnect(client, userdata, rc):
        print("⚠️ 与云端断开连接，尝试重连...")
        client.reconnect()

    client = mqtt.Client(CallbackAPIVersion.VERSION2, CLIENT_ID)
    client.username_pw_set(USERNAME, PASSWORD)
    client.on_connect = on_connect
    client.on_disconnect = on_disconnect
    client.connect(HOST, PORT)
    return client

client = connect_mqtt()
client.loop_start()

print("摄像头已启动 → 按 q 键停止")

# ==================== 辅助函数 ====================
def build_properties(results):
    """构造属性上报 JSON"""
    objs = []
    for box in results[0].boxes:
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])
        class_name = model.names[cls_id]
        objs.append({
            "类别": class_name,
            "置信度": round(conf, 2),
            "位置": [round(x, 2) for x in box.xyxy[0].tolist()]
        })
    return {
        "services": [{
            "service_id": "wheat-detection",
            "properties": {
                "检测目标数量": len(objs),
                "最高置信度": max([o["置信度"] for o in objs]) if objs else 0,
                "所有目标": objs,
                "时间戳": time.time()
            }
        }]
    }

def build_alert_event(results):
    """构造告警事件 JSON"""
    objs = []
    for box in results[0].boxes:
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])
        class_name = model.names[cls_id]
        objs.append({
            "病害类型": class_name,
            "置信度": round(conf, 2)
        })
    return {
        "services": [{
            "service_id": "wheat-detection",
            "event_time": time.strftime("%Y%m%dT%H%M%SZ", time.gmtime()),
            "event_id": "pest_detected",
            "event_type": "warning",
            "paras": {
                "目标列表": objs,
                "最高置信度": max([o["置信度"] for o in objs]) if objs else 0
            }
        }]
    }

# ==================== 上报控制变量 ====================
last_alert_time = 0
ALERT_COOLDOWN = 2       # 2 秒内不重复告警

last_upload_time = 0
UPLOAD_INTERVAL = 3     # 属性上报间隔 3 秒

# ==================== 实时检测循环 ====================
try:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("读取失败")
            break

        # YOLO 检测
        results = model(frame)
        frame_det = results[0].plot()

        current_time = time.time()

        # ------ 属性上报（每 3 秒）------
        if current_time - last_upload_time >= UPLOAD_INTERVAL:
            payload = build_properties(results)
            print(json.dumps(payload, ensure_ascii=False, indent=2))
            client.publish(TOPIC_PROPERTY, json.dumps(payload, ensure_ascii=False), qos=1)
            print(f"📡 属性上报：{json.dumps(payload, ensure_ascii=False, indent=2)}")
            last_upload_time = current_time

        # ------ 告警事件上报（检测到目标，且冷却时间已过）------
        if len(results[0].boxes) > 0 and (current_time - last_alert_time) >= ALERT_COOLDOWN:
            alert_json = build_alert_event(results)
            client.publish(TOPIC_ALERT, json.dumps(alert_json, ensure_ascii=False), qos=1)
            print(f"🚨 告警事件已推送：{json.dumps(alert_json, ensure_ascii=False, indent=2)}")
            last_alert_time = current_time

        # 显示画面
        frame_rgb = cv2.cvtColor(frame_det, cv2.COLOR_BGR2RGB)
        clear_output(wait=True)
        plt.imshow(frame_rgb)
        plt.title("小麦病虫害实时检测 - 已接入华为云", fontsize=16)
        plt.axis("off")
        plt.tight_layout()
        plt.show()

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

finally:
    cap.release()
    cv2.destroyAllWindows()
    client.loop_stop()
    client.disconnect()
    print("已停止检测，与云端连接已关闭")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 130
#     129 # YOLO 检测
# --> 130 results = model(frame)
#     131 frame_det = results[0].plot()
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     155 """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157 This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)
#     175     ...     print(f"Detected {len(r)} objects in image")
#     176 """
# --> 177 return self.predict(source, stream, **kwargs)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\engine\model.py:541, in Model.predict(self, source, stream, predictor, **kwargs)
#     540     self.predictor.set_prompts(prompts)
# --> 541 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\engine\predictor.py:228, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     227 else:
# --> 228     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\torch\utils\_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      39 with ctx_factory():
# ---> 40     response = gen.send(None)
#      42 while True:
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\engine\predictor.py:337, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     336 with profilers[1]:
# --> 337     preds = self.inference(im, *args, **kwargs)
#     338     if self.args.embed:
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\engine\predictor.py:185, in BasePredictor.inference(self, im, *args, **kwargs)
#     180 visualize = (
#     181     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     182     if self.args.visualize and (not self.source_type.tensor)
#     183     else False
#     184 )
# --> 185 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\nn\autobackend.py:278, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     276     forward_kwargs = {"augment": augment, "visualize": visualize, "embed": embed, **kwargs}
# --> 278 y = self.backend.forward(im, **forward_kwargs)
#     280 if isinstance(y, (list, tuple)):
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\nn\backends\pytorch.py:90, in PyTorchBackend.forward(self, im, augment, visualize, embed, **kwargs)
#      78 """Run native PyTorch inference with support for augmentation, visualization, and embeddings.
#      79
#      80 Args:
#    (...)
#      88     (torch.Tensor | list[torch.Tensor]): Model predictions as tensor(s).
#      89 """
# ---> 90 return self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\nn\tasks.py:154, in BaseModel.forward(self, x, *args, **kwargs)
#     153     return self.loss(x, *args, **kwargs)
# --> 154 return self.predict(x, *args, **kwargs)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\nn\tasks.py:171, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     170     return self._predict_augment(x)
# --> 171 return self._predict_once(x, profile, visualize, embed)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\ultralytics\nn\tasks.py:193, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     192     self._profile_one_layer(m, x, dt)
# --> 193 x = m(x)  # run
#     194 y.append(x if m.i in self.save else None)  # save output
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\torch\nn\modules\upsampling.py:174, in Upsample.forward(self, input)
#     171 """
#     172 Runs the forward pass.
#     173 """
# --> 174 return F.interpolate(
#     175     input,
#     176     self.size,
#     177     self.scale_factor,
#     178     self.mode,
#     179     self.align_corners,
#     180     recompute_scale_factor=self.recompute_scale_factor,
#     181 )
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\torch\nn\functional.py:4827, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4825 if input.dim() == 4 and mode == "nearest":
#    4826     # pyrefly: ignore [bad-argument-type]
# -> 4827     return torch._C._nn.upsample_nearest2d(input, output_size, scale_factors)
#    4828 if input.dim() == 5 and mode == "nearest":
#    4829     # pyrefly: ignore [bad-argument-type]
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 166
#     164 cv2.destroyAllWindows()
#     165 client.loop_stop()
# --> 166 client.disconnect()
#     167 print("已停止检测，与云端连接已关闭")
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\paho\mqtt\client.py:1892, in Client.disconnect(self, reasoncode, properties)
#    1889 else:
#    1890     self._state = _ConnectionState.MQTT_CS_DISCONNECTING
# -> 1892 return self._send_disconnect(reasoncode, properties)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\paho\mqtt\client.py:3610, in Client._send_disconnect(self, reasoncode, properties)
#    3607         if properties is not None:
#    3608             packet += packed_props
# -> 3610 return self._packet_queue(command, packet, 0, 0)
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\paho\mqtt\client.py:3791, in Client._packet_queue(self, command, packet, mid, qos, info)
#    3789     if self._in_callback_mutex.acquire(False):
#    3790         self._in_callback_mutex.release()
# -> 3791         return self.loop_write()
#    3793 self._call_socket_register_write()
#    3795 return MQTTErrorCode.MQTT_ERR_SUCCESS
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\paho\mqtt\client.py:2121, in Client.loop_write(self)
#    2118     return MQTTErrorCode.MQTT_ERR_NO_CONN
#    2120 try:
# -> 2121     rc = self._packet_write()
#    2122     if rc == MQTTErrorCode.MQTT_ERR_AGAIN:
#    2123         return MQTTErrorCode.MQTT_ERR_SUCCESS
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\paho\mqtt\client.py:3226, in Client._packet_write(self)
#    3223 with self._msgtime_mutex:
#    3224     self._last_msg_out = time_func()
# -> 3226 self._do_on_disconnect(
#    3227     packet_from_broker=False,
#    3228     v1_rc=MQTTErrorCode.MQTT_ERR_SUCCESS,
#    3229 )
#    3230 self._sock_close()
#    3231 # Only change to disconnected if the disconnection was wanted
#    3232 # by the client (== state was disconnecting). If the broker disconnected
#    3233 # use unilaterally don't change the state and client may reconnect.
#
# File D:\Anaconda\envs\torch_env_soft\lib\site-packages\paho\mqtt\client.py:4383, in Client._do_on_disconnect(self, packet_from_broker, v1_rc, reason, properties)
#    4380     if properties is None:
#    4381         properties = Properties(PacketTypes.DISCONNECT)
# -> 4383     on_disconnect(
#    4384         self,
#    4385         self._userdata,
#    4386         disconnect_flags,
#    4387         reason,
#    4388         properties,
#    4389     )
#    4390 else:
#    4391     raise RuntimeError("Unsupported callback API version")
#
# TypeError: connect_mqtt.<locals>.on_disconnect() takes 3 positional arguments but 5 were given
